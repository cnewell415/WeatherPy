# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
import citipy
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the nearest cities to the 2000 random cordinates
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
#len(cities)

#Test printing the list
print(cities[2])
# Out:
# belushya guba

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da5b3aacfa5bdd6b7ca4c617738022f7

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    
        
        # Weather Description
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Desc": city_weather_desc,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | tubmanburg
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | itarema
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | hutchinson
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | port-cartier
# Processing Record 11 of Set 1 | pemangkat
# Processing Record 12 of Set 1 | novopokrovka
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 1 | teacapan
# Processing Record 16 of Set 1 | tazovskiy
# Processing Record 17 of Set 1 | san cristobal
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | matamoros
# Processing Record 20 of Set 1 | salinas
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | pisco
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | surgut
# Processing Record 27 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | constitucion
# Processing Record 30 of Set 1 | hengyang
# Processing Record 31 of Set 1 | pula
# Processing Record 32 of Set 1 | sao filipe
# Processing Record 33 of Set 1 | havoysund
# Processing Record 34 of Set 1 | genhe
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | namatanai
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | evensk
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | cody
# Processing Record 41 of Set 1 | nampa
# Processing Record 42 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 1 | paucartambo
# City not found. Skipping...
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | adrar
# Processing Record 49 of Set 1 | maniitsoq
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 2 | lalpur
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | miramar
# Processing Record 5 of Set 2 | aksarka
# Processing Record 6 of Set 2 | port keats
# Processing Record 7 of Set 2 | shikarpur
# Processing Record 8 of Set 2 | abonnema
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | bonavista
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | fairfield
# Processing Record 13 of Set 2 | talca
# Processing Record 14 of Set 2 | northam
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | kavieng
# Processing Record 17 of Set 2 | baiyin
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | bathsheba
# Processing Record 21 of Set 2 | sayyan
# Processing Record 22 of Set 2 | palmares do sul
# Processing Record 23 of Set 2 | yeppoon
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | provideniya
# Processing Record 27 of Set 2 | dingle
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | nagua
# Processing Record 34 of Set 2 | pangnirtung
# Processing Record 35 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 2 | belsand
# Processing Record 37 of Set 2 | geraldton
# Processing Record 38 of Set 2 | grafton
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | rawson
# Processing Record 41 of Set 2 | sao joao da barra
# Processing Record 42 of Set 2 | erenhot
# Processing Record 43 of Set 2 | padang
# Processing Record 44 of Set 2 | pitanga
# Processing Record 45 of Set 2 | pangkalanbuun
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 2 | ishigaki
# Processing Record 49 of Set 2 | nanortalik
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | kirensk
# Processing Record 2 of Set 3 | nova varos
# Processing Record 3 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | nagorsk
# Processing Record 7 of Set 3 | bengkulu
# Processing Record 8 of Set 3 | huilong
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | banganapalle
# Processing Record 11 of Set 3 | bryan
# Processing Record 12 of Set 3 | colares
# Processing Record 13 of Set 3 | chandbali
# Processing Record 14 of Set 3 | waipawa
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | ulaangom
# Processing Record 17 of Set 3 | pokhara
# Processing Record 18 of Set 3 | mataura
# Processing Record 19 of Set 3 | lagoa
# Processing Record 20 of Set 3 | tiksi
# Processing Record 21 of Set 3 | nouadhibou
# Processing Record 22 of Set 3 | nyurba
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | dokri
# Processing Record 25 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 3 | reitoca
# Processing Record 27 of Set 3 | balabac
# Processing Record 28 of Set 3 | oussouye
# Processing Record 29 of Set 3 | bethel
# Processing Record 30 of Set 3 | san clemente
# Processing Record 31 of Set 3 | xining
# Processing Record 32 of Set 3 | wattegama
# Processing Record 33 of Set 3 | auki
# Processing Record 34 of Set 3 | tautira
# Processing Record 35 of Set 3 | talaya
# Processing Record 36 of Set 3 | kapaa
# Processing Record 37 of Set 3 | cherskiy
# Processing Record 38 of Set 3 | berlevag
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | lompoc
# Processing Record 41 of Set 3 | kutum
# Processing Record 42 of Set 3 | vila franca do campo
# Processing Record 43 of Set 3 | berdigestyakh
# Processing Record 44 of Set 3 | manaure
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | bolgar
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | gbarnga
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | krasnoborsk
# Processing Record 2 of Set 4 | san juan
# Processing Record 3 of Set 4 | marsh harbour
# Processing Record 4 of Set 4 | anuradhapura
# Processing Record 5 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | faanui
# Processing Record 8 of Set 4 | male
# Processing Record 9 of Set 4 | bambous virieux
# Processing Record 10 of Set 4 | phan thiet
# Processing Record 11 of Set 4 | varzea da palma
# Processing Record 12 of Set 4 | sangar
# Processing Record 13 of Set 4 | saint-philippe
# Processing Record 14 of Set 4 | souillac
# Processing Record 15 of Set 4 | japura
# Processing Record 16 of Set 4 | tiarei
# Processing Record 17 of Set 4 | coquimbo
# Processing Record 18 of Set 4 | swellendam
# Processing Record 19 of Set 4 | hot springs
# Processing Record 20 of Set 4 | yellowknife
# Processing Record 21 of Set 4 | sergeyevka
# Processing Record 22 of Set 4 | stribro
# Processing Record 23 of Set 4 | carnarvon
# Processing Record 24 of Set 4 | grindavik
# Processing Record 25 of Set 4 | leningradskiy
# Processing Record 26 of Set 4 | hambantota
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | dikson
# Processing Record 29 of Set 4 | narsaq
# Processing Record 30 of Set 4 | hamadan
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | saurimo
# Processing Record 33 of Set 4 | shimanovsk
# Processing Record 34 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 4 | batsfjord
# Processing Record 36 of Set 4 | adre
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | sakakah
# Processing Record 39 of Set 4 | ostrovnoy
# Processing Record 40 of Set 4 | eucaliptus
# Processing Record 41 of Set 4 | goderich
# Processing Record 42 of Set 4 | pinega
# Processing Record 43 of Set 4 | hargeysa
# Processing Record 44 of Set 4 | kalundborg
# Processing Record 45 of Set 4 | thunder bay
# Processing Record 46 of Set 4 | vallenar
# Processing Record 47 of Set 4 | mitchell
# Processing Record 48 of Set 4 | salalah
# Processing Record 49 of Set 4 | khatanga
# Processing Record 50 of Set 4 | upernavik
# Processing Record 1 of Set 5 | orsha
# Processing Record 2 of Set 5 | namibe
# Processing Record 3 of Set 5 | westport
# Processing Record 4 of Set 5 | lake havasu city
# Processing Record 5 of Set 5 | luderitz
# Processing Record 6 of Set 5 | samarai
# Processing Record 7 of Set 5 | muzhi
# Processing Record 8 of Set 5 | korla
# Processing Record 9 of Set 5 | liezen
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | simao
# Processing Record 12 of Set 5 | ondangwa
# Processing Record 13 of Set 5 | te anau
# Processing Record 14 of Set 5 | the valley
# Processing Record 15 of Set 5 | vicente guerrero
# Processing Record 16 of Set 5 | gold coast
# Processing Record 17 of Set 5 | taraza
# Processing Record 18 of Set 5 | riverton
# Processing Record 19 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 5 | cam ranh
# Processing Record 21 of Set 5 | new norfolk
# Processing Record 22 of Set 5 | victoria
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | bonawon
# Processing Record 25 of Set 5 | puerto el triunfo
# Processing Record 26 of Set 5 | prainha
# Processing Record 27 of Set 5 | lorengau
# Processing Record 28 of Set 5 | burica
# City not found. Skipping...
# Processing Record 29 of Set 5 | tiruchchendur
# Processing Record 30 of Set 5 | jining
# Processing Record 31 of Set 5 | saskylakh
# Processing Record 32 of Set 5 | abha
# Processing Record 33 of Set 5 | portland
# Processing Record 34 of Set 5 | torbay
# Processing Record 35 of Set 5 | olinda
# Processing Record 36 of Set 5 | margate
# Processing Record 37 of Set 5 | quatre cocos
# Processing Record 38 of Set 5 | iquique
# Processing Record 39 of Set 5 | asau
# Processing Record 40 of Set 5 | hithadhoo
# Processing Record 41 of Set 5 | klaksvik
# Processing Record 42 of Set 5 | bilma
# Processing Record 43 of Set 5 | broome
# Processing Record 44 of Set 5 | uong bi
# Processing Record 45 of Set 5 | barcelos
# Processing Record 46 of Set 5 | vao
# Processing Record 47 of Set 5 | kyela
# Processing Record 48 of Set 5 | usinsk
# Processing Record 49 of Set 5 | saint-augustin
# Processing Record 50 of Set 5 | norman wells
# Processing Record 1 of Set 6 | isla mujeres
# Processing Record 2 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 6 | ayorou
# Processing Record 4 of Set 6 | guozhen
# Processing Record 5 of Set 6 | ventspils
# Processing Record 6 of Set 6 | coihaique
# Processing Record 7 of Set 6 | avera
# Processing Record 8 of Set 6 | pacific grove
# Processing Record 9 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 10 of Set 6 | kurchum
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | talnakh
# Processing Record 13 of Set 6 | brufut
# Processing Record 14 of Set 6 | garowe
# Processing Record 15 of Set 6 | ossora
# Processing Record 16 of Set 6 | praia
# Processing Record 17 of Set 6 | tateyama
# Processing Record 18 of Set 6 | mecca
# Processing Record 19 of Set 6 | yulara
# Processing Record 20 of Set 6 | amga
# Processing Record 21 of Set 6 | fort nelson
# Processing Record 22 of Set 6 | kholodnyy
# Processing Record 23 of Set 6 | puerto suarez
# Processing Record 24 of Set 6 | meulaboh
# Processing Record 25 of Set 6 | cabedelo
# Processing Record 26 of Set 6 | novoagansk
# Processing Record 27 of Set 6 | ankang
# Processing Record 28 of Set 6 | vanderhoof
# Processing Record 29 of Set 6 | vostok
# Processing Record 30 of Set 6 | vardo
# Processing Record 31 of Set 6 | camana
# Processing Record 32 of Set 6 | mumford
# Processing Record 33 of Set 6 | lazaro cardenas
# Processing Record 34 of Set 6 | hailey
# Processing Record 35 of Set 6 | bani walid
# Processing Record 36 of Set 6 | cedar city
# Processing Record 37 of Set 6 | sembe
# Processing Record 38 of Set 6 | tilichiki
# Processing Record 39 of Set 6 | atascocita
# Processing Record 40 of Set 6 | diamantino
# Processing Record 41 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 6 | viesca
# Processing Record 43 of Set 6 | banjarmasin
# Processing Record 44 of Set 6 | roma
# Processing Record 45 of Set 6 | ilulissat
# Processing Record 46 of Set 6 | holland
# Processing Record 47 of Set 6 | usevya
# Processing Record 48 of Set 6 | laguna
# Processing Record 49 of Set 6 | muscat
# Processing Record 50 of Set 6 | porto san giorgio
# Processing Record 1 of Set 7 | honiara
# Processing Record 2 of Set 7 | bourail
# Processing Record 3 of Set 7 | hovd
# Processing Record 4 of Set 7 | butembo
# Processing Record 5 of Set 7 | lityn
# Processing Record 6 of Set 7 | paita
# Processing Record 7 of Set 7 | channel-port aux basques
# Processing Record 8 of Set 7 | longyearbyen
# Processing Record 9 of Set 7 | port blair
# Processing Record 10 of Set 7 | ebano
# City not found. Skipping...
# Processing Record 11 of Set 7 | berezovyy
# Processing Record 12 of Set 7 | noumea
# Processing Record 13 of Set 7 | blonduos
# City not found. Skipping...
# Processing Record 14 of Set 7 | barrhead
# Processing Record 15 of Set 7 | ivybridge
# Processing Record 16 of Set 7 | iskateley
# Processing Record 17 of Set 7 | comodoro rivadavia
# Processing Record 18 of Set 7 | hammerfest
# Processing Record 19 of Set 7 | piuma
# Processing Record 20 of Set 7 | orumiyeh
# Processing Record 21 of Set 7 | ust-tsilma
# Processing Record 22 of Set 7 | xiaoweizhai
# Processing Record 23 of Set 7 | huangchuan
# Processing Record 24 of Set 7 | barentin
# Processing Record 25 of Set 7 | hervey bay
# Processing Record 26 of Set 7 | hualmay
# Processing Record 27 of Set 7 | biloela
# Processing Record 28 of Set 7 | nishihara
# Processing Record 29 of Set 7 | pevek
# Processing Record 30 of Set 7 | vanimo
# Processing Record 31 of Set 7 | kavaratti
# Processing Record 32 of Set 7 | nioro
# Processing Record 33 of Set 7 | airai
# Processing Record 34 of Set 7 | zhangjiakou
# Processing Record 35 of Set 7 | yar-sale
# Processing Record 36 of Set 7 | aguilas
# Processing Record 37 of Set 7 | darab
# Processing Record 38 of Set 7 | kloulklubed
# Processing Record 39 of Set 7 | port macquarie
# Processing Record 40 of Set 7 | isangel
# Processing Record 41 of Set 7 | lebu
# Processing Record 42 of Set 7 | sterling
# Processing Record 43 of Set 7 | hasaki
# Processing Record 44 of Set 7 | lavrentiya
# Processing Record 45 of Set 7 | wolmaranstad
# City not found. Skipping...
# Processing Record 46 of Set 7 | chara
# Processing Record 47 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 7 | yangjiang
# Processing Record 49 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 7 | zhob
# Processing Record 1 of Set 8 | puerto madero
# Processing Record 2 of Set 8 | tawzar
# City not found. Skipping...
# Processing Record 3 of Set 8 | veinticinco de mayo
# Processing Record 4 of Set 8 | hirara
# Processing Record 5 of Set 8 | skibbereen
# Processing Record 6 of Set 8 | oktyabrskiy
# Processing Record 7 of Set 8 | tabuk
# Processing Record 8 of Set 8 | ottumwa
# Processing Record 9 of Set 8 | inuvik
# Processing Record 10 of Set 8 | dunedin
# Processing Record 11 of Set 8 | natal
# Processing Record 12 of Set 8 | turukhansk
# Processing Record 13 of Set 8 | maragogi
# Processing Record 14 of Set 8 | masty
# Processing Record 15 of Set 8 | moose factory
# Processing Record 16 of Set 8 | porto novo
# Processing Record 17 of Set 8 | bam
# Processing Record 18 of Set 8 | felipe carrillo puerto
# Processing Record 19 of Set 8 | narrabri
# Processing Record 20 of Set 8 | paamiut
# Processing Record 21 of Set 8 | ambilobe
# Processing Record 22 of Set 8 | bossangoa
# Processing Record 23 of Set 8 | hami
# Processing Record 24 of Set 8 | blagoyevo
# Processing Record 25 of Set 8 | chalmette
# Processing Record 26 of Set 8 | zyryanka
# Processing Record 27 of Set 8 | anloga
# Processing Record 28 of Set 8 | san buenaventura
# Processing Record 29 of Set 8 | bambanglipuro
# Processing Record 30 of Set 8 | puerto del rosario
# Processing Record 31 of Set 8 | nador
# Processing Record 32 of Set 8 | kahului
# Processing Record 33 of Set 8 | hamilton
# Processing Record 34 of Set 8 | roura
# Processing Record 35 of Set 8 | saint-pierre
# Processing Record 36 of Set 8 | alta floresta
# Processing Record 37 of Set 8 | balaipungut
# Processing Record 38 of Set 8 | lata
# Processing Record 39 of Set 8 | kaduqli
# Processing Record 40 of Set 8 | batangafo
# Processing Record 41 of Set 8 | kropotkin
# Processing Record 42 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 8 | bibiani
# Processing Record 44 of Set 8 | skalnyy
# City not found. Skipping...
# Processing Record 45 of Set 8 | nome
# Processing Record 46 of Set 8 | port lincoln
# Processing Record 47 of Set 8 | parana
# Processing Record 48 of Set 8 | college
# Processing Record 49 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of Set 8 | qostanay
# Processing Record 1 of Set 9 | bako
# Processing Record 2 of Set 9 | walvis bay
# Processing Record 3 of Set 9 | kudahuvadhoo
# Processing Record 4 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 9 | humaita
# Processing Record 6 of Set 9 | xai-xai
# Processing Record 7 of Set 9 | brae
# Processing Record 8 of Set 9 | charters towers
# Processing Record 9 of Set 9 | grootfontein
# Processing Record 10 of Set 9 | nikolayevsk-na-amure
# Processing Record 11 of Set 9 | tessalit
# Processing Record 12 of Set 9 | kupang
# Processing Record 13 of Set 9 | stornoway
# Processing Record 14 of Set 9 | makakilo city
# Processing Record 15 of Set 9 | abilene
# Processing Record 16 of Set 9 | peruibe
# Processing Record 17 of Set 9 | ahtopol
# Processing Record 18 of Set 9 | castelbuono
# Processing Record 19 of Set 9 | bandarbeyla
# Processing Record 20 of Set 9 | ostersund
# Processing Record 21 of Set 9 | jalu
# Processing Record 22 of Set 9 | san julian
# Processing Record 23 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 9 | we
# City not found. Skipping...
# Processing Record 25 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 26 of Set 9 | lhokseumawe
# Processing Record 27 of Set 9 | invermere
# Processing Record 28 of Set 9 | novikovo
# Processing Record 29 of Set 9 | sept-iles
# Processing Record 30 of Set 9 | port-gentil
# Processing Record 31 of Set 9 | koutsouras
# Processing Record 32 of Set 9 | guasdualito
# Processing Record 33 of Set 9 | talagante
# Processing Record 34 of Set 9 | codrington
# Processing Record 35 of Set 9 | susice
# Processing Record 36 of Set 9 | sungaipenuh
# Processing Record 37 of Set 9 | macherla
# Processing Record 38 of Set 9 | camacha
# Processing Record 39 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 9 | esperance
# Processing Record 41 of Set 9 | vestmanna
# Processing Record 42 of Set 9 | gasa
# Processing Record 43 of Set 9 | sioux lookout
# Processing Record 44 of Set 9 | thinadhoo
# Processing Record 45 of Set 9 | la gaulette
# City not found. Skipping...
# Processing Record 46 of Set 9 | alofi
# Processing Record 47 of Set 9 | labrea
# Processing Record 48 of Set 9 | vidalia
# Processing Record 49 of Set 9 | saint anthony
# Processing Record 50 of Set 9 | yaya
# Processing Record 1 of Set 10 | ahipara
# Processing Record 2 of Set 10 | kununurra
# Processing Record 3 of Set 10 | komsomolskiy
# Processing Record 4 of Set 10 | basoko
# Processing Record 5 of Set 10 | altagracia de orituco
# Processing Record 6 of Set 10 | sao felix do xingu
# Processing Record 7 of Set 10 | merauke
# Processing Record 8 of Set 10 | luanda
# Processing Record 9 of Set 10 | xalpatlahuac
# Processing Record 10 of Set 10 | motygino
# Processing Record 11 of Set 10 | zhoucheng
# Processing Record 12 of Set 10 | luanshya
# Processing Record 13 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 14 of Set 10 | corowa
# Processing Record 15 of Set 10 | coron
# Processing Record 16 of Set 10 | andra
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | pyatnitskoye
# Processing Record 19 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 10 | maan
# Processing Record 21 of Set 10 | tokmak
# Processing Record 22 of Set 10 | mayo
# Processing Record 23 of Set 10 | labuhan
# Processing Record 24 of Set 10 | lucea
# Processing Record 25 of Set 10 | benton
# Processing Record 26 of Set 10 | mindelo
# Processing Record 27 of Set 10 | mount gambier
# Processing Record 28 of Set 10 | bubaque
# Processing Record 29 of Set 10 | odweyne
# Processing Record 30 of Set 10 | fuzhou
# Processing Record 31 of Set 10 | marzuq
# Processing Record 32 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 10 | vengerovo
# Processing Record 34 of Set 10 | savannah bight
# Processing Record 35 of Set 10 | husavik
# Processing Record 36 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 37 of Set 10 | sorkjosen
# Processing Record 38 of Set 10 | la rioja
# Processing Record 39 of Set 10 | kobayashi
# Processing Record 40 of Set 10 | chokurdakh
# Processing Record 41 of Set 10 | krasnoselkup
# Processing Record 42 of Set 10 | otanche
# Processing Record 43 of Set 10 | tayu
# Processing Record 44 of Set 10 | kugulta
# Processing Record 45 of Set 10 | chitipa
# Processing Record 46 of Set 10 | kousseri
# Processing Record 47 of Set 10 | mandalgovi
# Processing Record 48 of Set 10 | itirucu
# Processing Record 49 of Set 10 | zhigansk
# Processing Record 50 of Set 10 | chuy
# Processing Record 1 of Set 11 | dimapur
# Processing Record 2 of Set 11 | trincomalee
# Processing Record 3 of Set 11 | caravelas
# Processing Record 4 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 11 | behbahan
# Processing Record 6 of Set 11 | aizkraukle
# Processing Record 7 of Set 11 | betioky
# Processing Record 8 of Set 11 | saldanha
# Processing Record 9 of Set 11 | tulun
# Processing Record 10 of Set 11 | kuminskiy
# Processing Record 11 of Set 11 | beira
# Processing Record 12 of Set 11 | porto seguro
# Processing Record 13 of Set 11 | aksaray
# Processing Record 14 of Set 11 | axim
# Processing Record 15 of Set 11 | fare
# Processing Record 16 of Set 11 | cruz do espirito santo
# Processing Record 17 of Set 11 | ajdabiya
# Processing Record 18 of Set 11 | clinton
# Processing Record 19 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 11 | lodwar
# Processing Record 21 of Set 11 | sorland
# Processing Record 22 of Set 11 | umm kaddadah
# Processing Record 23 of Set 11 | sedhiou
# Processing Record 24 of Set 11 | tura
# Processing Record 25 of Set 11 | faya
# Processing Record 26 of Set 11 | marshall
# Processing Record 27 of Set 11 | nachingwea
# Processing Record 28 of Set 11 | rutana
# Processing Record 29 of Set 11 | south yuba city
# Processing Record 30 of Set 11 | cradock
# Processing Record 31 of Set 11 | taoudenni
# Processing Record 32 of Set 11 | vaitape
# Processing Record 33 of Set 11 | santa isabel do rio negro
# Processing Record 34 of Set 11 | upington
# Processing Record 35 of Set 11 | estepona
# Processing Record 36 of Set 11 | marawi
# Processing Record 37 of Set 11 | yefira
# City not found. Skipping...
# Processing Record 38 of Set 11 | brajrajnagar
# City not found. Skipping...
# Processing Record 39 of Set 11 | korhogo
# Processing Record 40 of Set 11 | sokolka
# Processing Record 41 of Set 11 | fairbanks
# Processing Record 42 of Set 11 | sapa
# Processing Record 43 of Set 11 | huambo
# Processing Record 44 of Set 11 | goundam
# Processing Record 45 of Set 11 | presidente dutra
# Processing Record 46 of Set 11 | medvedok
# Processing Record 47 of Set 11 | knin
# Processing Record 48 of Set 11 | vestmannaeyjar
# Processing Record 49 of Set 11 | vila velha
# Processing Record 50 of Set 11 | belyy yar
# Processing Record 1 of Set 12 | osakarovka
# Processing Record 2 of Set 12 | otautau
# Processing Record 3 of Set 12 | ayaviri
# Processing Record 4 of Set 12 | antofagasta
# Processing Record 5 of Set 12 | muros
# Processing Record 6 of Set 12 | dubbo
# Processing Record 7 of Set 12 | grand gaube
# Processing Record 8 of Set 12 | cobija
# Processing Record 9 of Set 12 | deputatskiy
# Processing Record 10 of Set 12 | solnechnyy
# Processing Record 11 of Set 12 | hobyo
# Processing Record 12 of Set 12 | arlit
# Processing Record 13 of Set 12 | kerema
# Processing Record 14 of Set 12 | mama
# Processing Record 15 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 12 | zonguldak
# Processing Record 17 of Set 12 | san lorenzo
# Processing Record 18 of Set 12 | skjervoy
# Processing Record 19 of Set 12 | gidam
# Processing Record 20 of Set 12 | uvira
# Processing Record 21 of Set 12 | loreto
# Processing Record 22 of Set 12 | manzanillo
# Processing Record 23 of Set 12 | teahupoo
# Processing Record 24 of Set 12 | caldwell
# Processing Record 25 of Set 12 | yelanskiy
# Processing Record 26 of Set 12 | nelson bay
# Processing Record 27 of Set 12 | liverpool
# Processing Record 28 of Set 12 | lakes entrance
# Processing Record 29 of Set 12 | yomou
# Processing Record 30 of Set 12 | kasongo-lunda
# Processing Record 31 of Set 12 | zheleznodorozhnyy
# Processing Record 32 of Set 12 | tuatapere
# Processing Record 33 of Set 12 | lesnoy
# Processing Record 34 of Set 12 | dongsheng
# Processing Record 35 of Set 12 | dali
# Processing Record 36 of Set 12 | udachnyy
# Processing Record 37 of Set 12 | kasempa
# Processing Record 38 of Set 12 | ekpoma
# Processing Record 39 of Set 12 | olafsvik
# Processing Record 40 of Set 12 | belaya gora
# Processing Record 41 of Set 12 | shache
# Processing Record 42 of Set 12 | zhezkazgan
# Processing Record 43 of Set 12 | potot
# Processing Record 44 of Set 12 | naze
# Processing Record 45 of Set 12 | obo
# Processing Record 46 of Set 12 | alice springs
# Processing Record 47 of Set 12 | sitka
# Processing Record 48 of Set 12 | ornskoldsvik
# Processing Record 49 of Set 12 | karpathos
# Processing Record 50 of Set 12 | ayan
# Processing Record 1 of Set 13 | lixourion
# Processing Record 2 of Set 13 | manicore
# Processing Record 3 of Set 13 | kruisfontein
# Processing Record 4 of Set 13 | majene
# Processing Record 5 of Set 13 | carutapera
# Processing Record 6 of Set 13 | putina
# Processing Record 7 of Set 13 | bairiki
# Processing Record 8 of Set 13 | nizhniy baskunchak
# Processing Record 9 of Set 13 | chicama
# Processing Record 10 of Set 13 | baykit
# Processing Record 11 of Set 13 | sibolga
# Processing Record 12 of Set 13 | praya
# Processing Record 13 of Set 13 | wuwei
# Processing Record 14 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 13 | kushiro
# Processing Record 16 of Set 13 | dawlatabad
# Processing Record 17 of Set 13 | taupo
# Processing Record 18 of Set 13 | derzhavinsk
# Processing Record 19 of Set 13 | lichuan
# Processing Record 20 of Set 13 | engen
# Processing Record 21 of Set 13 | zhashkiv
# Processing Record 22 of Set 13 | aguas formosas
# Processing Record 23 of Set 13 | jiwani
# Processing Record 24 of Set 13 | acapulco
# Processing Record 25 of Set 13 | maceio
# Processing Record 26 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 13 | gravdal
# Processing Record 29 of Set 13 | sawakin
# Processing Record 30 of Set 13 | sangmelima
# Processing Record 31 of Set 13 | peniche
# Processing Record 32 of Set 13 | sapele
# Processing Record 33 of Set 13 | sola
# Processing Record 34 of Set 13 | sao paulo de olivenca
# Processing Record 35 of Set 13 | san patricio
# Processing Record 36 of Set 13 | chatsu
# City not found. Skipping...
# Processing Record 37 of Set 13 | hisai
# Processing Record 38 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 13 | altamira
# Processing Record 40 of Set 13 | ubala
# Processing Record 41 of Set 13 | riyadh
# Processing Record 42 of Set 13 | puri
# Processing Record 43 of Set 13 | mehamn
# Processing Record 44 of Set 13 | rocha
# Processing Record 45 of Set 13 | itapirapua
# Processing Record 46 of Set 13 | la ronge
# Processing Record 47 of Set 13 | valleyview
# Processing Record 48 of Set 13 | biltine
# Processing Record 49 of Set 13 | orocue
# Processing Record 50 of Set 13 | werda
# Processing Record 1 of Set 14 | ojinaga
# Processing Record 2 of Set 14 | keuruu
# Processing Record 3 of Set 14 | ardatov
# Processing Record 4 of Set 14 | pacifica
# Processing Record 5 of Set 14 | bobcaygeon
# Processing Record 6 of Set 14 | gilazi
# City not found. Skipping...
# Processing Record 7 of Set 14 | tomatlan
# Processing Record 8 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 14 | campo verde
# Processing Record 10 of Set 14 | christchurch
# Processing Record 11 of Set 14 | iracoubo
# Processing Record 12 of Set 14 | gambela
# Processing Record 13 of Set 14 | flinders
# Processing Record 14 of Set 14 | mazagao
# Processing Record 15 of Set 14 | yaan
# Processing Record 16 of Set 14 | gazanjyk
# Processing Record 17 of Set 14 | inhambane
# Processing Record 18 of Set 14 | panjwin
# City not found. Skipping...
# Processing Record 19 of Set 14 | nortelandia
# Processing Record 20 of Set 14 | novyy urgal
# Processing Record 21 of Set 14 | beloha
# Processing Record 22 of Set 14 | tenenkou
# Processing Record 23 of Set 14 | cornelio procopio
# Processing Record 24 of Set 14 | manggar
# Processing Record 25 of Set 14 | pistsovo
# Processing Record 26 of Set 14 | leshukonskoye
# Processing Record 27 of Set 14 | taunton
# Processing Record 28 of Set 14 | ushtobe
# Processing Record 29 of Set 14 | atar
# Processing Record 30 of Set 14 | jumla
# Processing Record 31 of Set 14 | sao luiz gonzaga
# Processing Record 32 of Set 14 | muli
# Processing Record 33 of Set 14 | xuddur
# Processing Record 34 of Set 14 | banda aceh
# Processing Record 35 of Set 14 | bitkine
# Processing Record 36 of Set 14 | miri
# Processing Record 37 of Set 14 | mafinga
# Processing Record 38 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 40 of Set 14 | maxixe
# Processing Record 41 of Set 14 | wilmington
# Processing Record 42 of Set 14 | arawa
# Processing Record 43 of Set 14 | los llanos de aridane
# Processing Record 44 of Set 14 | elizabeth city
# Processing Record 45 of Set 14 | sainte-anne-des-monts
# Processing Record 46 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 47 of Set 14 | klokkarvik
# City not found. Skipping...
# Processing Record 48 of Set 14 | matagami
# Processing Record 49 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 14 | terra santa
# Processing Record 1 of Set 15 | la baule-escoublac
# Processing Record 2 of Set 15 | talakan
# Processing Record 3 of Set 15 | rio brilhante
# Processing Record 4 of Set 15 | kondopoga
# Processing Record 5 of Set 15 | sinnamary
# Processing Record 6 of Set 15 | suhbaatar
# Processing Record 7 of Set 15 | mach
# Processing Record 8 of Set 15 | mabaruma
# Processing Record 9 of Set 15 | sinazongwe
# Processing Record 10 of Set 15 | buribay
# Processing Record 11 of Set 15 | bac lieu
# Processing Record 12 of Set 15 | kaeo
# Processing Record 13 of Set 15 | finnsnes
# Processing Record 14 of Set 15 | la victoria
# Processing Record 15 of Set 15 | salamiyah
# Processing Record 16 of Set 15 | kysyl-syr
# Processing Record 17 of Set 15 | san matias
# Processing Record 18 of Set 15 | inirida
# Processing Record 19 of Set 15 | qaqortoq
# Processing Record 20 of Set 15 | chanute
# Processing Record 21 of Set 15 | bacolod
# Processing Record 22 of Set 15 | harper
# Processing Record 23 of Set 15 | bud
# Processing Record 24 of Set 15 | tshikapa
# Processing Record 25 of Set 15 | zelenogorskiy
# Processing Record 26 of Set 15 | nosy varika
# Processing Record 27 of Set 15 | tocopilla
# Processing Record 28 of Set 15 | tupelo
# Processing Record 29 of Set 15 | dunhua
# Processing Record 30 of Set 15 | chapais
# Processing Record 31 of Set 15 | antequera
# Processing Record 32 of Set 15 | pak phanang
# Processing Record 33 of Set 15 | moba
# Processing Record 34 of Set 15 | linqiong
# Processing Record 35 of Set 15 | gunjur
# Processing Record 36 of Set 15 | kargil
# Processing Record 37 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 38 of Set 15 | tabou
# Processing Record 39 of Set 15 | rochegda
# Processing Record 40 of Set 15 | monrovia
# Processing Record 41 of Set 15 | manzhouli
# Processing Record 42 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 43 of Set 15 | emba
# Processing Record 44 of Set 15 | clyde river
# Processing Record 45 of Set 15 | batemans bay
# Processing Record 46 of Set 15 | coihueco
# Processing Record 47 of Set 15 | itaueira
# Processing Record 48 of Set 15 | marsa matruh
# Processing Record 49 of Set 15 | mato verde
# Processing Record 50 of Set 15 | mount isa
# Processing Record 1 of Set 16 | sunbury
# Processing Record 2 of Set 16 | waingapu
# Processing Record 3 of Set 16 | antibes
# Processing Record 4 of Set 16 | pitimbu
# Processing Record 5 of Set 16 | bijni
# Processing Record 6 of Set 16 | valdez
# Processing Record 7 of Set 16 | emilio carranza
# Processing Record 8 of Set 16 | morgan city
# Processing Record 9 of Set 16 | baracoa
# Processing Record 10 of Set 16 | rio gallegos
# Processing Record 11 of Set 16 | oranjestad
# Processing Record 12 of Set 16 | havelock
# Processing Record 13 of Set 16 | vasterhaninge
# Processing Record 14 of Set 16 | nipawin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
#convert array of dictionaries to Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth -33.9180   25.5701     62.89        77           0
# 1      Tubmanburg   6.8708  -10.8172     73.11        91         100
# 2          Kodiak  57.7900 -152.4072     44.11        76          75
# 3          Hobart -42.8794  147.3294     59.25        57          20
# 4         Itarema  -2.9248  -39.9167     80.08        77           3
# 5           Bluff -46.6000  168.3333     58.80        85         100
# 6      Hutchinson  38.0608  -97.9298     69.75        17           0
# 7            Hilo  19.7297 -155.0900     80.33        79          40
# 8    Port-Cartier  50.0334  -66.8654      7.02        83          29
# 9       Pemangkat   1.1667  108.9667     74.70        91          94
#
#    Wind Speed Country      Weather Desc                 Date
# 0        3.44      ZA         clear sky  2022-02-21 22:34:18
# 1        1.52      LR   overcast clouds  2022-02-21 22:34:18
# 2       12.66      US     broken clouds  2022-02-21 22:34:19
# 3        8.05      AU        few clouds  2022-02-21 22:31:52
# 4       15.19      BR         clear sky  2022-02-21 22:34:19
# 5       18.37      NZ   overcast clouds  2022-02-21 22:31:01
# 6        0.00      US         clear sky  2022-02-21 22:32:26
# 7        8.05      US  scattered clouds  2022-02-21 22:30:37
# 8        7.36      CA  scattered clouds  2022-02-21 22:34:19
# 9        6.31      ID   overcast clouds  2022-02-21 22:34:19

# %%
#reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Desc"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth      ZA -33.9180   25.5701     62.89        77           0
# 1      Tubmanburg      LR   6.8708  -10.8172     73.11        91         100
# 2          Kodiak      US  57.7900 -152.4072     44.11        76          75
# 3          Hobart      AU -42.8794  147.3294     59.25        57          20
# 4         Itarema      BR  -2.9248  -39.9167     80.08        77           3
# 5           Bluff      NZ -46.6000  168.3333     58.80        85         100
# 6      Hutchinson      US  38.0608  -97.9298     69.75        17           0
# 7            Hilo      US  19.7297 -155.0900     80.33        79          40
# 8    Port-Cartier      CA  50.0334  -66.8654      7.02        83          29
# 9       Pemangkat      ID   1.1667  108.9667     74.70        91          94
#
#    Wind Speed      Weather Desc
# 0        3.44         clear sky
# 1        1.52   overcast clouds
# 2       12.66     broken clouds
# 3        8.05        few clouds
# 4       15.19         clear sky
# 5       18.37   overcast clouds
# 6        0.00         clear sky
# 7        8.05  scattered clouds
# 8        7.36  scattered clouds
# 9        6.31   overcast clouds

# %%
#Create output file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export Dataframe to CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
