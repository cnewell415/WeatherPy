# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
import citipy
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the nearest cities to the 2000 random cordinates
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
#len(cities)

#Test printing the list
print(cities[2])
# Out:
# lolua

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da5b3aacfa5bdd6b7ca4c617738022f7

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    
        
        # Weather Description
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Desc": city_weather_desc,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | sakakah
# Processing Record 3 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | bambanglipuro
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | henties bay
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | ryotsu
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | vao
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | balkhash
# Processing Record 19 of Set 1 | sao filipe
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | kloulklubed
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | altay
# Processing Record 26 of Set 1 | jalu
# Processing Record 27 of Set 1 | bud
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | lieksa
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | portland
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | saint anthony
# Processing Record 37 of Set 1 | mehamn
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | richards bay
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | klaksvik
# Processing Record 44 of Set 1 | asau
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | cherskiy
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | polunochnoye
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | tateyama
# Processing Record 2 of Set 2 | the pas
# Processing Record 3 of Set 2 | boguszow-gorce
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | udachnyy
# Processing Record 6 of Set 2 | bonthe
# Processing Record 7 of Set 2 | derzhavinsk
# Processing Record 8 of Set 2 | tome-acu
# City not found. Skipping...
# Processing Record 9 of Set 2 | artyom
# Processing Record 10 of Set 2 | salym
# Processing Record 11 of Set 2 | shymkent
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | sitka
# Processing Record 14 of Set 2 | katobu
# Processing Record 15 of Set 2 | qax
# Processing Record 16 of Set 2 | semnan
# Processing Record 17 of Set 2 | kapoeta
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | jaciara
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | rio grande
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | cherepanovo
# Processing Record 28 of Set 2 | yertsevo
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | hualmay
# Processing Record 34 of Set 2 | genhe
# Processing Record 35 of Set 2 | korla
# Processing Record 36 of Set 2 | rundu
# Processing Record 37 of Set 2 | ilulissat
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | makakilo city
# Processing Record 42 of Set 2 | boa vista
# Processing Record 43 of Set 2 | waipawa
# Processing Record 44 of Set 2 | rovaniemi
# Processing Record 45 of Set 2 | inongo
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | cidreira
# Processing Record 48 of Set 2 | xinzhou
# Processing Record 49 of Set 2 | vostok
# Processing Record 50 of Set 2 | asfi
# Processing Record 1 of Set 3 | whitehorse
# Processing Record 2 of Set 3 | mecca
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | kathmandu
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | acuitzio
# Processing Record 7 of Set 3 | barra dos coqueiros
# Processing Record 8 of Set 3 | winneba
# Processing Record 9 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 13 of Set 3 | zhezkazgan
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 3 | szentgotthard
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | taybad
# Processing Record 19 of Set 3 | pacifica
# Processing Record 20 of Set 3 | kudahuvadhoo
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | glendive
# Processing Record 23 of Set 3 | kandry
# Processing Record 24 of Set 3 | westport
# Processing Record 25 of Set 3 | chapais
# Processing Record 26 of Set 3 | kavieng
# Processing Record 27 of Set 3 | oum hadjer
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | hazorasp
# Processing Record 30 of Set 3 | port alberni
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | tuatapere
# Processing Record 33 of Set 3 | the valley
# Processing Record 34 of Set 3 | tomaszow lubelski
# Processing Record 35 of Set 3 | zwedru
# Processing Record 36 of Set 3 | mataura
# Processing Record 37 of Set 3 | baherden
# Processing Record 38 of Set 3 | kharp
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | graaff-reinet
# Processing Record 41 of Set 3 | kalabo
# Processing Record 42 of Set 3 | havelock
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | cabo san lucas
# Processing Record 46 of Set 3 | puerto escondido
# Processing Record 47 of Set 3 | vardo
# Processing Record 48 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 3 | batsfjord
# Processing Record 50 of Set 3 | iqaluit
# Processing Record 1 of Set 4 | dikson
# Processing Record 2 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 4 | evenskjaer
# City not found. Skipping...
# Processing Record 4 of Set 4 | sayla
# Processing Record 5 of Set 4 | upernavik
# Processing Record 6 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | nome
# Processing Record 9 of Set 4 | kruisfontein
# Processing Record 10 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 4 | dawlatabad
# Processing Record 12 of Set 4 | vestmannaeyjar
# Processing Record 13 of Set 4 | leh
# Processing Record 14 of Set 4 | yaan
# Processing Record 15 of Set 4 | praia da vitoria
# Processing Record 16 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 4 | mount gambier
# Processing Record 18 of Set 4 | cayenne
# Processing Record 19 of Set 4 | belyy yar
# Processing Record 20 of Set 4 | zhigalovo
# Processing Record 21 of Set 4 | harper
# Processing Record 22 of Set 4 | port blair
# Processing Record 23 of Set 4 | temiscaming
# Processing Record 24 of Set 4 | tigil
# Processing Record 25 of Set 4 | gramsh
# Processing Record 26 of Set 4 | zachary
# Processing Record 27 of Set 4 | atuona
# Processing Record 28 of Set 4 | chandia
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | lebu
# Processing Record 31 of Set 4 | kologriv
# Processing Record 32 of Set 4 | tuy hoa
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | tecoanapa
# Processing Record 35 of Set 4 | granja
# Processing Record 36 of Set 4 | kobojango
# City not found. Skipping...
# Processing Record 37 of Set 4 | caravelas
# Processing Record 38 of Set 4 | meulaboh
# Processing Record 39 of Set 4 | vytegra
# Processing Record 40 of Set 4 | andros town
# Processing Record 41 of Set 4 | chokurdakh
# Processing Record 42 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 4 | pafos
# Processing Record 44 of Set 4 | gamba
# Processing Record 45 of Set 4 | anahawan
# Processing Record 46 of Set 4 | novo cruzeiro
# Processing Record 47 of Set 4 | cochrane
# Processing Record 48 of Set 4 | fuyu
# Processing Record 49 of Set 4 | anadyr
# Processing Record 50 of Set 4 | maragogi
# Processing Record 1 of Set 5 | patacamaya
# Processing Record 2 of Set 5 | san jose
# Processing Record 3 of Set 5 | carutapera
# Processing Record 4 of Set 5 | tuktoyaktuk
# Processing Record 5 of Set 5 | visby
# Processing Record 6 of Set 5 | erice
# Processing Record 7 of Set 5 | arrecife
# Processing Record 8 of Set 5 | lompoc
# Processing Record 9 of Set 5 | nanakuli
# Processing Record 10 of Set 5 | luanda
# Processing Record 11 of Set 5 | great yarmouth
# Processing Record 12 of Set 5 | verkhoyansk
# Processing Record 13 of Set 5 | pangai
# Processing Record 14 of Set 5 | mayo
# Processing Record 15 of Set 5 | kununurra
# Processing Record 16 of Set 5 | belur
# Processing Record 17 of Set 5 | meiktila
# Processing Record 18 of Set 5 | matagami
# Processing Record 19 of Set 5 | hami
# Processing Record 20 of Set 5 | chicama
# Processing Record 21 of Set 5 | buchanan
# Processing Record 22 of Set 5 | mouila
# Processing Record 23 of Set 5 | ouro preto do oeste
# Processing Record 24 of Set 5 | gizo
# Processing Record 25 of Set 5 | berlevag
# Processing Record 26 of Set 5 | fort wellington
# Processing Record 27 of Set 5 | butembo
# Processing Record 28 of Set 5 | wokha
# Processing Record 29 of Set 5 | talnakh
# Processing Record 30 of Set 5 | vitim
# Processing Record 31 of Set 5 | alenquer
# Processing Record 32 of Set 5 | dejen
# Processing Record 33 of Set 5 | arman
# Processing Record 34 of Set 5 | isiro
# Processing Record 35 of Set 5 | olinda
# Processing Record 36 of Set 5 | iquique
# Processing Record 37 of Set 5 | jiuquan
# Processing Record 38 of Set 5 | logrono
# Processing Record 39 of Set 5 | mookane
# Processing Record 40 of Set 5 | uturoa
# Processing Record 41 of Set 5 | san patricio
# Processing Record 42 of Set 5 | lagos
# Processing Record 43 of Set 5 | coolum beach
# Processing Record 44 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 45 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 5 | sarlat-la-caneda
# Processing Record 48 of Set 5 | bara
# Processing Record 49 of Set 5 | grindavik
# Processing Record 50 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | mbandaka
# Processing Record 2 of Set 6 | camacha
# Processing Record 3 of Set 6 | lasa
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | chara
# Processing Record 6 of Set 6 | jasper
# Processing Record 7 of Set 6 | lukovetskiy
# Processing Record 8 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 6 | ghorawal
# Processing Record 10 of Set 6 | kombissiri
# Processing Record 11 of Set 6 | kuhdasht
# Processing Record 12 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 6 | jinchang
# Processing Record 14 of Set 6 | karlstad
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | hebi
# Processing Record 17 of Set 6 | zabinka
# City not found. Skipping...
# Processing Record 18 of Set 6 | pauini
# Processing Record 19 of Set 6 | kirksville
# Processing Record 20 of Set 6 | coruripe
# Processing Record 21 of Set 6 | college
# Processing Record 22 of Set 6 | srisailam
# Processing Record 23 of Set 6 | portobelo
# Processing Record 24 of Set 6 | termoli
# Processing Record 25 of Set 6 | poum
# Processing Record 26 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 6 | severo-kurilsk
# Processing Record 28 of Set 6 | baykit
# Processing Record 29 of Set 6 | newport
# Processing Record 30 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | taoudenni
# Processing Record 32 of Set 6 | licheng
# Processing Record 33 of Set 6 | krasnaya gorbatka
# Processing Record 34 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 6 | nouadhibou
# Processing Record 36 of Set 6 | padang
# Processing Record 37 of Set 6 | avera
# Processing Record 38 of Set 6 | san quintin
# Processing Record 39 of Set 6 | neryungri
# Processing Record 40 of Set 6 | nantucket
# Processing Record 41 of Set 6 | saint marys
# Processing Record 42 of Set 6 | abu dhabi
# Processing Record 43 of Set 6 | partizan
# Processing Record 44 of Set 6 | coro
# Processing Record 45 of Set 6 | arraial do cabo
# Processing Record 46 of Set 6 | howard springs
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | matou
# Processing Record 49 of Set 6 | srandakan
# Processing Record 50 of Set 6 | yar-sale
# Processing Record 1 of Set 7 | shimoda
# Processing Record 2 of Set 7 | moranbah
# Processing Record 3 of Set 7 | gunjur
# Processing Record 4 of Set 7 | goderich
# Processing Record 5 of Set 7 | haapiti
# Processing Record 6 of Set 7 | huarmey
# Processing Record 7 of Set 7 | kasongo-lunda
# Processing Record 8 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 9 of Set 7 | luangwa
# Processing Record 10 of Set 7 | geraldton
# Processing Record 11 of Set 7 | chuy
# Processing Record 12 of Set 7 | ugoofaaru
# Processing Record 13 of Set 7 | sidi qasim
# City not found. Skipping...
# Processing Record 14 of Set 7 | coquimbo
# Processing Record 15 of Set 7 | angra
# City not found. Skipping...
# Processing Record 16 of Set 7 | soanierana ivongo
# Processing Record 17 of Set 7 | luebo
# Processing Record 18 of Set 7 | bambous virieux
# Processing Record 19 of Set 7 | ponta do sol
# Processing Record 20 of Set 7 | pokrovsk
# Processing Record 21 of Set 7 | ayan
# Processing Record 22 of Set 7 | salamanca
# Processing Record 23 of Set 7 | kristianstad
# Processing Record 24 of Set 7 | beloha
# Processing Record 25 of Set 7 | bubaque
# Processing Record 26 of Set 7 | srednekolymsk
# Processing Record 27 of Set 7 | nanortalik
# Processing Record 28 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 7 | torbay
# Processing Record 31 of Set 7 | nipawin
# Processing Record 32 of Set 7 | yeppoon
# Processing Record 33 of Set 7 | kieta
# Processing Record 34 of Set 7 | pisco
# Processing Record 35 of Set 7 | mbacke
# City not found. Skipping...
# Processing Record 36 of Set 7 | koson
# Processing Record 37 of Set 7 | naze
# Processing Record 38 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 39 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 40 of Set 7 | auxerre
# Processing Record 41 of Set 7 | sinnai
# Processing Record 42 of Set 7 | mao
# Processing Record 43 of Set 7 | georgetown
# Processing Record 44 of Set 7 | shingu
# Processing Record 45 of Set 7 | lagoa
# Processing Record 46 of Set 7 | los llanos de aridane
# Processing Record 47 of Set 7 | ribeira grande
# Processing Record 48 of Set 7 | canico
# Processing Record 49 of Set 7 | gat
# Processing Record 50 of Set 7 | rocha
# Processing Record 1 of Set 8 | khandyga
# Processing Record 2 of Set 8 | norman wells
# Processing Record 3 of Set 8 | vila do maio
# Processing Record 4 of Set 8 | metro
# Processing Record 5 of Set 8 | kalmunai
# Processing Record 6 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 7 of Set 8 | hasaki
# Processing Record 8 of Set 8 | clyde river
# Processing Record 9 of Set 8 | boguchany
# Processing Record 10 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 11 of Set 8 | la ronge
# Processing Record 12 of Set 8 | slave lake
# Processing Record 13 of Set 8 | cobija
# Processing Record 14 of Set 8 | constitucion
# Processing Record 15 of Set 8 | santa maria
# Processing Record 16 of Set 8 | canto do buriti
# Processing Record 17 of Set 8 | ligayan
# Processing Record 18 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 8 | talakan
# Processing Record 20 of Set 8 | pyinmana
# Processing Record 21 of Set 8 | rodrigues alves
# Processing Record 22 of Set 8 | ochakiv
# Processing Record 23 of Set 8 | bobbili
# Processing Record 24 of Set 8 | monte alegre de minas
# Processing Record 25 of Set 8 | kabanjahe
# Processing Record 26 of Set 8 | menongue
# Processing Record 27 of Set 8 | necochea
# Processing Record 28 of Set 8 | road town
# Processing Record 29 of Set 8 | xining
# Processing Record 30 of Set 8 | paamiut
# Processing Record 31 of Set 8 | uige
# Processing Record 32 of Set 8 | novoseleznevo
# Processing Record 33 of Set 8 | nisia floresta
# Processing Record 34 of Set 8 | fortuna
# Processing Record 35 of Set 8 | rio gallegos
# Processing Record 36 of Set 8 | kalasin
# Processing Record 37 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 8 | general pico
# Processing Record 39 of Set 8 | brewster
# Processing Record 40 of Set 8 | royan
# Processing Record 41 of Set 8 | kaitangata
# Processing Record 42 of Set 8 | znamenskoye
# Processing Record 43 of Set 8 | akdepe
# Processing Record 44 of Set 8 | haines junction
# Processing Record 45 of Set 8 | saint-georges
# Processing Record 46 of Set 8 | oistins
# Processing Record 47 of Set 8 | oranjestad
# Processing Record 48 of Set 8 | kuznetsk
# Processing Record 49 of Set 8 | gazanjyk
# Processing Record 50 of Set 8 | vila franca do campo
# Processing Record 1 of Set 9 | harsin
# Processing Record 2 of Set 9 | taksimo
# Processing Record 3 of Set 9 | yumen
# Processing Record 4 of Set 9 | rawson
# Processing Record 5 of Set 9 | dolgorukovo
# Processing Record 6 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 9 | rocky mountain house
# Processing Record 8 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 9 | san policarpo
# Processing Record 10 of Set 9 | creel
# Processing Record 11 of Set 9 | san benedetto del tronto
# Processing Record 12 of Set 9 | ajdabiya
# Processing Record 13 of Set 9 | walvis bay
# Processing Record 14 of Set 9 | timra
# Processing Record 15 of Set 9 | faanui
# Processing Record 16 of Set 9 | nassjo
# Processing Record 17 of Set 9 | bela
# Processing Record 18 of Set 9 | faya
# Processing Record 19 of Set 9 | cesis
# Processing Record 20 of Set 9 | marzuq
# Processing Record 21 of Set 9 | yulara
# Processing Record 22 of Set 9 | san cristobal
# Processing Record 23 of Set 9 | havre-saint-pierre
# Processing Record 24 of Set 9 | mount isa
# Processing Record 25 of Set 9 | emba
# Processing Record 26 of Set 9 | ust-nera
# Processing Record 27 of Set 9 | ilo
# Processing Record 28 of Set 9 | phnum penh
# City not found. Skipping...
# Processing Record 29 of Set 9 | batagay
# Processing Record 30 of Set 9 | bafoulabe
# Processing Record 31 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 9 | ostrovnoy
# Processing Record 33 of Set 9 | maunabo
# Processing Record 34 of Set 9 | boca do acre
# Processing Record 35 of Set 9 | narsaq
# Processing Record 36 of Set 9 | burica
# City not found. Skipping...
# Processing Record 37 of Set 9 | comodoro rivadavia
# Processing Record 38 of Set 9 | erzin
# Processing Record 39 of Set 9 | upington
# Processing Record 40 of Set 9 | aklavik
# Processing Record 41 of Set 9 | santander
# Processing Record 42 of Set 9 | kozhva
# Processing Record 43 of Set 9 | tomohon
# Processing Record 44 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 9 | bandarbeyla
# Processing Record 46 of Set 9 | wad rawah
# Processing Record 47 of Set 9 | piojo
# Processing Record 48 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 49 of Set 9 | rafai
# Processing Record 50 of Set 9 | le vauclin
# Processing Record 1 of Set 10 | ajaccio
# Processing Record 2 of Set 10 | luderitz
# Processing Record 3 of Set 10 | moram
# Processing Record 4 of Set 10 | namatanai
# Processing Record 5 of Set 10 | zalantun
# Processing Record 6 of Set 10 | hambantota
# Processing Record 7 of Set 10 | stawell
# Processing Record 8 of Set 10 | banjar
# Processing Record 9 of Set 10 | aras
# Processing Record 10 of Set 10 | goure
# Processing Record 11 of Set 10 | freeport
# Processing Record 12 of Set 10 | kuryk
# Processing Record 13 of Set 10 | lazurne
# Processing Record 14 of Set 10 | sangar
# Processing Record 15 of Set 10 | deputatskiy
# Processing Record 16 of Set 10 | tando ghulam ali
# Processing Record 17 of Set 10 | mahibadhoo
# Processing Record 18 of Set 10 | veinticinco de mayo
# Processing Record 19 of Set 10 | valenzuela
# Processing Record 20 of Set 10 | moron
# Processing Record 21 of Set 10 | chernyshevskiy
# Processing Record 22 of Set 10 | torquay
# Processing Record 23 of Set 10 | cotoca
# Processing Record 24 of Set 10 | tutla
# City not found. Skipping...
# Processing Record 25 of Set 10 | lorengau
# Processing Record 26 of Set 10 | marawi
# Processing Record 27 of Set 10 | kajaani
# Processing Record 28 of Set 10 | chiknayakanhalli
# Processing Record 29 of Set 10 | pitimbu
# Processing Record 30 of Set 10 | luau
# Processing Record 31 of Set 10 | touros
# Processing Record 32 of Set 10 | fukue
# Processing Record 33 of Set 10 | colares
# Processing Record 34 of Set 10 | eseka
# Processing Record 35 of Set 10 | seymchan
# Processing Record 36 of Set 10 | lac du bonnet
# Processing Record 37 of Set 10 | berbera
# Processing Record 38 of Set 10 | cururupu
# Processing Record 39 of Set 10 | morris
# Processing Record 40 of Set 10 | azul
# Processing Record 41 of Set 10 | tazmalt
# Processing Record 42 of Set 10 | conakry
# Processing Record 43 of Set 10 | ankola
# Processing Record 44 of Set 10 | churapcha
# Processing Record 45 of Set 10 | port lincoln
# Processing Record 46 of Set 10 | melfi
# Processing Record 47 of Set 10 | buala
# Processing Record 48 of Set 10 | kragujevac
# Processing Record 49 of Set 10 | longyan
# Processing Record 50 of Set 10 | qom
# Processing Record 1 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 2 of Set 11 | formiga
# Processing Record 3 of Set 11 | jerez
# Processing Record 4 of Set 11 | sobolevo
# Processing Record 5 of Set 11 | kampot
# Processing Record 6 of Set 11 | itaberai
# Processing Record 7 of Set 11 | atar
# Processing Record 8 of Set 11 | hovd
# Processing Record 9 of Set 11 | pedreiras
# Processing Record 10 of Set 11 | kazachinskoye
# Processing Record 11 of Set 11 | launceston
# Processing Record 12 of Set 11 | vallenar
# Processing Record 13 of Set 11 | nongstoin
# Processing Record 14 of Set 11 | tura
# Processing Record 15 of Set 11 | doha
# Processing Record 16 of Set 11 | barcelos
# Processing Record 17 of Set 11 | vanimo
# Processing Record 18 of Set 11 | nabire
# Processing Record 19 of Set 11 | guaymas
# Processing Record 20 of Set 11 | sivas
# Processing Record 21 of Set 11 | kahului
# Processing Record 22 of Set 11 | cocorit
# Processing Record 23 of Set 11 | huallanca
# Processing Record 24 of Set 11 | kargasok
# Processing Record 25 of Set 11 | crotone
# Processing Record 26 of Set 11 | grand gaube
# Processing Record 27 of Set 11 | okha
# Processing Record 28 of Set 11 | laguna
# Processing Record 29 of Set 11 | hamilton
# Processing Record 30 of Set 11 | wilmington
# Processing Record 31 of Set 11 | napoleon
# Processing Record 32 of Set 11 | tazovskiy
# Processing Record 33 of Set 11 | charters towers
# Processing Record 34 of Set 11 | port keats
# Processing Record 35 of Set 11 | toora-khem
# Processing Record 36 of Set 11 | wuwei
# Processing Record 37 of Set 11 | port-gentil
# Processing Record 38 of Set 11 | monrovia
# Processing Record 39 of Set 11 | hare bay
# Processing Record 40 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 11 | arrifes
# Processing Record 42 of Set 11 | yoichi
# Processing Record 43 of Set 11 | abha
# Processing Record 44 of Set 11 | katsuura
# Processing Record 45 of Set 11 | biak
# Processing Record 46 of Set 11 | sint michiel
# City not found. Skipping...
# Processing Record 47 of Set 11 | uyuni
# Processing Record 48 of Set 11 | matara
# Processing Record 49 of Set 11 | kalmar
# Processing Record 50 of Set 11 | auki
# Processing Record 1 of Set 12 | humaita
# Processing Record 2 of Set 12 | pontes e lacerda
# Processing Record 3 of Set 12 | pangnirtung
# Processing Record 4 of Set 12 | guerrero negro
# Processing Record 5 of Set 12 | vieste
# Processing Record 6 of Set 12 | twin falls
# Processing Record 7 of Set 12 | spencer
# Processing Record 8 of Set 12 | caledon
# Processing Record 9 of Set 12 | salcedo
# Processing Record 10 of Set 12 | mizdah
# Processing Record 11 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 12 | komsomolskiy
# Processing Record 13 of Set 12 | zyryanka
# Processing Record 14 of Set 12 | lodwar
# Processing Record 15 of Set 12 | piacabucu
# Processing Record 16 of Set 12 | cockburn town
# Processing Record 17 of Set 12 | moses lake
# Processing Record 18 of Set 12 | mogadishu
# Processing Record 19 of Set 12 | domat
# Processing Record 20 of Set 12 | bethanien
# Processing Record 21 of Set 12 | kargat
# Processing Record 22 of Set 12 | gao
# Processing Record 23 of Set 12 | wanning
# Processing Record 24 of Set 12 | chodziez
# Processing Record 25 of Set 12 | zambezi
# Processing Record 26 of Set 12 | lavrentiya
# Processing Record 27 of Set 12 | kamir
# Processing Record 28 of Set 12 | kamenka
# Processing Record 29 of Set 12 | abomsa
# Processing Record 30 of Set 12 | umm kaddadah
# Processing Record 31 of Set 12 | luena
# Processing Record 32 of Set 12 | takoradi
# Processing Record 33 of Set 12 | severo-yeniseyskiy
# Processing Record 34 of Set 12 | da nang
# Processing Record 35 of Set 12 | odessa
# Processing Record 36 of Set 12 | batagay-alyta
# Processing Record 37 of Set 12 | camopi
# Processing Record 38 of Set 12 | pouembout
# Processing Record 39 of Set 12 | tilichiki
# Processing Record 40 of Set 12 | saint-augustin
# Processing Record 41 of Set 12 | wajima
# Processing Record 42 of Set 12 | kismayo
# Processing Record 43 of Set 12 | danane
# Processing Record 44 of Set 12 | husavik
# Processing Record 45 of Set 12 | marin
# Processing Record 46 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 12 | binghamton
# Processing Record 48 of Set 12 | dirba
# Processing Record 49 of Set 12 | ustka
# Processing Record 50 of Set 12 | tadine
# Processing Record 1 of Set 13 | labuhan
# Processing Record 2 of Set 13 | sinnamary
# Processing Record 3 of Set 13 | nokaneng
# Processing Record 4 of Set 13 | lazaro cardenas
# Processing Record 5 of Set 13 | la capilla
# Processing Record 6 of Set 13 | amos
# Processing Record 7 of Set 13 | yeehaw junction
# City not found. Skipping...
# Processing Record 8 of Set 13 | seoul
# Processing Record 9 of Set 13 | savannah bight
# Processing Record 10 of Set 13 | honiara
# Processing Record 11 of Set 13 | tres arroyos
# Processing Record 12 of Set 13 | ati
# Processing Record 13 of Set 13 | te anau
# Processing Record 14 of Set 13 | pathalgaon
# Processing Record 15 of Set 13 | raudeberg
# Processing Record 16 of Set 13 | sambava
# Processing Record 17 of Set 13 | huilong
# Processing Record 18 of Set 13 | sechura
# Processing Record 19 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 20 of Set 13 | ulaangom
# Processing Record 21 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 22 of Set 13 | parit buntar
# Processing Record 23 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 13 | carlsbad
# Processing Record 25 of Set 13 | qasigiannguit
# Processing Record 26 of Set 13 | smithers
# Processing Record 27 of Set 13 | hobyo
# Processing Record 28 of Set 13 | karratha
# Processing Record 29 of Set 13 | saint-joseph
# Processing Record 30 of Set 13 | tanda
# Processing Record 31 of Set 13 | nuuk
# Processing Record 32 of Set 13 | shitanjing
# Processing Record 33 of Set 13 | dukat
# Processing Record 34 of Set 13 | port hedland
# Processing Record 35 of Set 13 | holme
# Processing Record 36 of Set 13 | mudyuga
# City not found. Skipping...
# Processing Record 37 of Set 13 | puri
# Processing Record 38 of Set 13 | itoman
# Processing Record 39 of Set 13 | beinamar
# Processing Record 40 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 13 | tinskoy
# Processing Record 42 of Set 13 | mnogovershinnyy
# Processing Record 43 of Set 13 | souillac
# Processing Record 44 of Set 13 | uberaba
# Processing Record 45 of Set 13 | baiyin
# Processing Record 46 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 13 | erenhot
# Processing Record 48 of Set 13 | grimshaw
# Processing Record 49 of Set 13 | henderson
# Processing Record 50 of Set 13 | nision
# Processing Record 1 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 14 | nouakchott
# Processing Record 3 of Set 14 | chute-aux-outardes
# Processing Record 4 of Set 14 | clermont
# Processing Record 5 of Set 14 | ukiah
# Processing Record 6 of Set 14 | zapolyarnyy
# Processing Record 7 of Set 14 | termiz
# Processing Record 8 of Set 14 | agadez
# Processing Record 9 of Set 14 | port-cartier
# Processing Record 10 of Set 14 | hurghada
# Processing Record 11 of Set 14 | myaundzha
# Processing Record 12 of Set 14 | miri
# Processing Record 13 of Set 14 | oxford
# Processing Record 14 of Set 14 | kamina
# Processing Record 15 of Set 14 | bundaberg
# Processing Record 16 of Set 14 | noumea
# Processing Record 17 of Set 14 | mandera
# Processing Record 18 of Set 14 | coahuayana
# Processing Record 19 of Set 14 | victor harbor
# Processing Record 20 of Set 14 | belem
# Processing Record 21 of Set 14 | duluth
# Processing Record 22 of Set 14 | hays
# Processing Record 23 of Set 14 | olesnica
# Processing Record 24 of Set 14 | namibe
# Processing Record 25 of Set 14 | dubbo
# Processing Record 26 of Set 14 | golden
# Processing Record 27 of Set 14 | roald
# Processing Record 28 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 14 | karasuk
# Processing Record 30 of Set 14 | itamaraca
# Processing Record 31 of Set 14 | torit
# Processing Record 32 of Set 14 | kingman
# Processing Record 33 of Set 14 | poros
# Processing Record 34 of Set 14 | washington
# Processing Record 35 of Set 14 | dhidhdhoo
# Processing Record 36 of Set 14 | aykhal
# Processing Record 37 of Set 14 | tlaxiaco
# City not found. Skipping...
# Processing Record 38 of Set 14 | pascagoula
# Processing Record 39 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 14 | kibaya
# Processing Record 41 of Set 14 | kavali
# Processing Record 42 of Set 14 | cam ranh
# Processing Record 43 of Set 14 | moose factory
# Processing Record 44 of Set 14 | sorong
# Processing Record 45 of Set 14 | konstantinovka
# Processing Record 46 of Set 14 | zetaquira
# Processing Record 47 of Set 14 | puro
# Processing Record 48 of Set 14 | ternate
# Processing Record 49 of Set 14 | liverpool
# Processing Record 50 of Set 14 | monywa
# Processing Record 1 of Set 15 | hernani
# Processing Record 2 of Set 15 | muros
# Processing Record 3 of Set 15 | isla vista
# Processing Record 4 of Set 15 | gucheng
# Processing Record 5 of Set 15 | ponta delgada
# Processing Record 6 of Set 15 | jambi
# Processing Record 7 of Set 15 | bollnas
# Processing Record 8 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 15 | matamoros
# Processing Record 10 of Set 15 | tabou
# Processing Record 11 of Set 15 | pangoa
# Processing Record 12 of Set 15 | merauke
# Processing Record 13 of Set 15 | kurilsk
# Processing Record 14 of Set 15 | shadrinsk
# Processing Record 15 of Set 15 | port augusta
# Processing Record 16 of Set 15 | khani
# Processing Record 17 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 15 | jagdalpur
# Processing Record 19 of Set 15 | funehiki
# Processing Record 20 of Set 15 | beringovskiy
# Processing Record 21 of Set 15 | mossendjo
# Processing Record 22 of Set 15 | padilla
# Processing Record 23 of Set 15 | yangjiang
# Processing Record 24 of Set 15 | yima
# Processing Record 25 of Set 15 | eyl
# Processing Record 26 of Set 15 | sturgis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 659

# %%
#convert array of dictionaries to Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Thompson  55.7435  -97.8558     -5.64        54          75
# 1        Sakakah  29.9697   40.2064     72.97        21         100
# 2        Ushuaia -54.8000  -68.3000     53.26        50          75
# 3  Bambanglipuro  -7.9500  110.2833     75.38        90         100
# 4      Mahebourg -20.4081   57.7000     80.89        83          75
# 5    Henties Bay -22.1160   14.2845     63.86        82           9
# 6         Barrow  71.2906 -156.7887    -15.38       100         100
# 7   Saint George  37.1041 -113.5841     70.27        28           0
# 8         Ryotsu  38.0833  138.4333     44.29        70         100
# 9           Hilo  19.7297 -155.0900     79.25        72         100
#
#    Wind Speed Country     Weather Desc                 Date
# 0       14.97      CA    broken clouds  2022-03-02 18:34:58
# 1        9.44      SA  overcast clouds  2022-03-02 18:34:59
# 2       13.80      AR    broken clouds  2022-03-02 18:34:28
# 3        6.17      ID  overcast clouds  2022-03-02 18:34:59
# 4       13.80      MU    broken clouds  2022-03-02 18:34:59
# 5        9.69      NA        clear sky  2022-03-02 18:35:00
# 6        4.45      US  overcast clouds  2022-03-02 18:35:00
# 7        1.01      US        clear sky  2022-03-02 18:34:02
# 8       15.37      JP       light rain  2022-03-02 18:35:00
# 9        8.05      US  overcast clouds  2022-03-02 18:31:23

# %%
#reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Desc"]
city_data_df = city_data_df[new_column_order]
city_data_df = city_data_df.rename(columns={"Weather Desc":"Current Description"})
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Thompson      CA  55.7435  -97.8558     -5.64        54          75
# 1        Sakakah      SA  29.9697   40.2064     72.97        21         100
# 2        Ushuaia      AR -54.8000  -68.3000     53.26        50          75
# 3  Bambanglipuro      ID  -7.9500  110.2833     75.38        90         100
# 4      Mahebourg      MU -20.4081   57.7000     80.89        83          75
# 5    Henties Bay      NA -22.1160   14.2845     63.86        82           9
# 6         Barrow      US  71.2906 -156.7887    -15.38       100         100
# 7   Saint George      US  37.1041 -113.5841     70.27        28           0
# 8         Ryotsu      JP  38.0833  138.4333     44.29        70         100
# 9           Hilo      US  19.7297 -155.0900     79.25        72         100
#
#    Wind Speed Current Description
# 0       14.97       broken clouds
# 1        9.44     overcast clouds
# 2       13.80       broken clouds
# 3        6.17     overcast clouds
# 4       13.80       broken clouds
# 5        9.69           clear sky
# 6        4.45     overcast clouds
# 7        1.01           clear sky
# 8       15.37          light rain
# 9        8.05     overcast clouds

# %%
#Create output file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export Dataframe to CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
